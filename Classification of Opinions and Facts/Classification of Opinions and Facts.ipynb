# %% [markdown]
# # Classification of Facts and Opinions
# ---

# %%
import pandas as pd

# %%
fact = pd.read_csv("FactData.csv")
opinion = pd.read_csv("OpinionData.csv")

# %%
fact['CATEGORY'] = 'fact'
fact.head()
# Out:
#    ID                                           HEADLINE  \
# 0   1  ‘Delhi CM does not speak for India’: Centre re...
# 1   2  Adhikari, Mukul Roy: CBI chargesheet seeks nod...
# 2   3  IFFCO CEO among those booked for importing fer...
# 3   4  Bombay HC pulls up Centre for hesitancy in ado...
# 4   5  Amid flak over fertiliser price rise, Centre h...
#
#                                                STORY CATEGORY
# 0  The Ministry of External Affairs (MEA), too, t...     fact
# 1  The application for prosecution of Adhikari an...     fact
# 2  The agency Wednesday conducted searches at 12 ...     fact
# 3  A division bench of Chief Justice Dipankar Dat...     fact
# 4  The increase in subsidy for DAP fertilisers wi...     fact

# %%
opinion['CATEGORY'] = 'opinion'
opinion.head()
# Out:
#    ID                                           HEADLINE  \
# 0   1  Adhikari, Mukul Roy: CBI chargesheet seeks nod...
# 1   2  IFFCO CEO among those booked for importing fer...
# 2   3  Bombay HC pulls up Centre for hesitancy in ado...
# 3   4  Amid flak over fertiliser price rise, Centre h...
# 4   5  Coimbatore temple consecrates ‘Corona Devi’ id...
#
#                                                STORY CATEGORY
# 0  The application for prosecution of Adhikari an...  opinion
# 1  The agency Wednesday conducted searches at 12 ...  opinion
# 2  A division bench of Chief Justice Dipankar Dat...  opinion
# 3  The increase in subsidy for DAP fertilisers wi...  opinion
# 4  Anand Bharathi, the manager of Kamatchipuri Ad...  opinion

# %%
df = pd.concat([opinion,fact])
df = df.sample(frac=1).reset_index(drop=True)
df.head(20)
# Out:
#       ID                                           HEADLINE  \
# 0   6241                                       It takes two
# 1   1199                            Downloading a debt trap
# 2   1924  WhatsApp working on password-protected chats b...
# 3    373  Seeking ‘discharge’ against framing of charges...
# 4   2054                                      Faster in IPL
# 5    463    April 3, 1981, Forty Years Ago: Hope In Gujarat
# 6   4623  Skincare tips: Use these three ingredients to ...
# 7   3154  Kangana Ranaut shares Covid-19 negative report...
# 8   1954  Forty Years Ago, November 3, 1980: Army pumps oil
# 9   3335                                     Moth and flame
# 10  5651  Delaying, not asking questions, on J&K — this ...
# 11  3681  Anushka Sharma says she, husband Virat Kohli a...
# 12   712  UP extends lockdown till May 6 morning, announ...
# 13  2004  Mobile phones under Rs 10,000 in India: List o...
# 14  6454  Joe Biden makes case to redefine role for gove...
# 15  4663  A tale of two states: As hopes fade for Amarav...
# 16  6174                                  Constitution Girl
# 17  6369                                      Like the wind
# 18  5563  Prakash Padukone recovering from COVID-19 infe...
# 19  3857  Farhan Akhtar trolled after he questions price...
#
#                                                 STORY CATEGORY
# 0   Opposition’s demand for sending bills to parli...  opinion
# 1   How unregulated lending apps preyed on financi...  opinion
# 2   The screenshots posted reveal how the chat bac...     fact
# 3   A three-judge bench headed by Chief Justice N ...     fact
# 4   Pace has been all the rage this season, changi...  opinion
# 5   This is the front page of The Indian Express p...  opinion
# 6   "Whether the cause is genetics or the environm...     fact
# 7   Sharing her negative Covid-19 report on her In...     fact
# 8   The Army was firmly on the Assam scene, facili...  opinion
# 9   Sushant Singh Rajput managed not only to break...  opinion
# 10  Deferring and delaying, not asking questions t...  opinion
# 11  Anushka Sharma, who celebrated her birthday on...     fact
# 12  Government has also issued directions to engag...     fact
# 13  Mobile Phones Under Rs 10,000 in India 2021: H...     fact
# 14  Taken together, the collection of initiatives ...     fact
# 15  It was said that Telangana was a rich state wi...  opinion
# 16  The video of a Russian teenager laying down th...  opinion
# 17  Dutee Chand again shows her ability to leave e...  opinion
# 18  Prakash Padukone has taken his first dose of t...     fact
# 19  Farhan Akhtar questioned Serum Institute India...     fact

# %%
df.shape
# Out:
# (13710, 4)

# %% [markdown]
# ## Cleaning headlines

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13710 entries, 0 to 13709
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        13710 non-null  int64
#  1   HEADLINE  13710 non-null  object
#  2   STORY     13710 non-null  object
#  3   CATEGORY  13710 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 428.6+ KB

# %%
df.isnull().sum()
# Out:
# ID          0
# HEADLINE    0
# STORY       0
# CATEGORY    0
# dtype: int64

# %%
import nltk
special_char = ['(<br/>)','(<a).*(>).*(</a>)','(&amp)','(&gt)','(&lt)','(\xa0)']

# %%
#LOWERCASE CONVERT
df['STORY'] = df['STORY'].apply(lambda x: x.lower())
df['HEADLINE'] = df['HEADLINE'].apply(lambda x: x.lower())

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
df['STORY'] = df['STORY'].apply(lambda x: " ".join(x for x in x.split() if x not in stopwords))
df['HEADLINE'] = df['HEADLINE'].apply(lambda x: " ".join(x for x in x.split() if x not in stopwords))

# %%
# Remove Rare words
#Firstly finding frequency of each word
freq = pd.Series(" ".join(df['STORY']).split()).value_counts()
less_freq = list(freq[freq==1].index)

# %%
df['STORY'] = df['STORY'].apply(lambda x: " ".join(x for x in x.split() if x not in less_freq))

# %%
df['ID']=df['ID'].index

# %%
df
# Out:
#           ID                                           HEADLINE  \
# 0          0                                          takes two
# 1          1                              downloading debt trap
# 2          2  whatsapp working password-protected chats back...
# 3          3  seeking ‘discharge’ framing charges valuable r...
# 4          4                                         faster ipl
# ...      ...                                                ...
# 13705  13705  india opened prematurely, dr fauci tells us se...
# 13706  13706  day goa prescribes ivermectin prophylaxis covi...
# 13707  13707  fifa takes point implementing newer ‘super’ pr...
# 13708  13708                                     house must sit
# 13709  13709  t20 world cup unsafe india, better play there:...
#
#                                                    STORY CATEGORY
# 0      opposition’s demand sending bills parliamentar...  opinion
# 1      unregulated lending apps financial uncertainty...  opinion
# 2      screenshots posted reveal chat backup work wha...     fact
# 3      three-judge bench headed chief justice n v ram...     fact
# 4      pace rage season, changing games, mocking patt...  opinion
# ...                                                  ...      ...
# 13705  india severely affected unprecedented second w...     fact
# 13706  march, too, recommended drug ivermectin used w...     fact
# 13707  fifa club world cup expanded relatively low-ke...     fact
# 13708  echo chambers good solutions. parliament open ...  opinion
# 13709  cummins feels hindsight always provides better...     fact
#
# [13710 rows x 4 columns]

# %%
# Again punctuation removal
df['HEADLINE'] = df['HEADLINE'].str.replace('[^\w\s]', '')
df['STORY'] = df['STORY'].str.replace('[^\w\s]', '')

# %%
df2 = df['HEADLINE'].apply(lambda x: len(x))

# %%
df2.describe()
# Out:
# count    13710.000000
# mean        51.905398
# std         22.742297
# min          0.000000
# 25%         39.000000
# 50%         55.000000
# 75%         67.000000
# max        142.000000
# Name: HEADLINE, dtype: float64

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
df_final = df[['HEADLINE','CATEGORY']]
df_final
# Out:
#                                                 HEADLINE CATEGORY
# 0                                              takes two  opinion
# 1                                  downloading debt trap  opinion
# 2      whatsapp working passwordprotected chats backu...     fact
# 3      seeking discharge framing charges valuable rig...     fact
# 4                                             faster ipl  opinion
# ...                                                  ...      ...
# 13705  india opened prematurely dr fauci tells us sen...     fact
# 13706  day goa prescribes ivermectin prophylaxis covi...     fact
# 13707  fifa takes point implementing newer super proj...     fact
# 13708                                     house must sit  opinion
# 13709  t20 world cup unsafe india better play there p...     fact
#
# [13710 rows x 2 columns]

# %%
train, test = train_test_split(df,test_size=0.2,random_state=42,shuffle=True)

# %%
train
# Out:
#           ID                                           HEADLINE  \
# 9124    9124                                      right redress
# 6713    6713  arranging oxygen distributing food needy karna...
# 11446  11446  mindless development could bring calamities li...
# 11947  11947  government runs huge deficit tackle crisis ask...
# 11756  11756  pitted oneplus 9 pros camera apples iphone 12 ...
# ...      ...                                                ...
# 5191    5191  scottish nationalists vow independence vote el...
# 13418  13418  jiofiber offering extra 30 days validity annua...
# 5390    5390                                     rulebook alone
# 860      860  malayalam screenwriterdirector dennis joseph p...
# 7270    7270      story indian democracy written blood betrayal
#
#                                                    STORY CATEGORY
# 9124   statutory backing msp makes economic sense far...  opinion
# 6713   police officers layout police station bengalur...     fact
# 11446  people want risk homes fields forests rivers n...  opinion
# 11947  india come present crisis little damage possib...  opinion
# 11756  oneplus 9 pro apple iphone 12 pro max offer be...     fact
# ...                                                  ...      ...
# 5191   first minister nicola said result meant would ...     fact
# 13418  jiofiber plans 2021 buying 100mbps annual broa...     fact
# 5390   regime laws enough deal pollution civil societ...  opinion
# 860    malayalam screenwriterdirector dennis joseph p...     fact
# 7270   bjp thinks going indianise kashmir instead see...  opinion
#
# [10968 rows x 4 columns]

# %%
test
# Out:
#           ID                                           HEADLINE  \
# 7592    7592  kiren rijiju tests positive several leaders in...
# 10974  10974       transfer saga big names looking change clubs
# 13272  13272  expect china intensify pressure campaign tsai ...
# 12659  12659                                   whos afraid song
# 2117    2117  refresh hibiscus flowers colourful millet sala...
# ...      ...                                                ...
# 17        17                                          like wind
# 7518    7518           forty years ago april 22 1981 uspak deal
# 9418    9418             70 pm modi come represent spirit times
# 1883    1883  suriyastarrer soorarai pottru selected shangha...
# 4874    4874  twitter ban kangana ranaut experts see action ...
#
#                                                    STORY CATEGORY
# 7592   union minister state youth affairs sports mini...     fact
# 10974  mbappe kane  big names changing clubs could th...     fact
# 13272  question consider going forward whether beijin...  opinion
# 12659  needs embrace students protested caa singing f...  opinion
# 2117                          get ready summers two easy     fact
# ...                                                  ...      ...
# 17     dutee chand shows ability leave everyone else ...  opinion
# 7518   united states offered pakistan accepted fiveye...  opinion
# 9418   imbibed deep insights human nature oxford indi...  opinion
# 1883   produced suriya banner soorarai pottru release...     fact
# 4874   twitters permanent ban bollywood actor kangana...     fact
#
# [2742 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(min_df = 5, max_df = 0.8, sublinear_tf = True, use_idf = True)

train_vectors = vectorizer.fit_transform(train['HEADLINE'])
test_vectors = vectorizer.transform(test['HEADLINE'])

# %%
import time
from sklearn import svm
from sklearn.metrics import classification_report

classifier_linear = svm.SVC(kernel='linear')
t0 = time.time()
classifier_linear.fit(train_vectors, train['CATEGORY'])
t1 = time.time()
prediction_linear = classifier_linear.predict(test_vectors)
t2 = time.time()
time_linear_train = t1-t0
time_linear_predict = t2-t1

print("Training time: %fs; Prediction time: %fs" % (time_linear_train, time_linear_predict))
report = classification_report(test['CATEGORY'], prediction_linear, output_dict=True)
print('opinion: ', report['opinion'])
print('fact: ', report['fact'])
# Out:
# Training time: 14.721190s; Prediction time: 2.293276s
# opinion:  {'precision': 0.8708730741012473, 'recall': 0.8965256797583081, 'f1-score': 0.8835132117603275, 'support': 1324}
# fact:  {'precision': 0.9006526468455403, 'recall': 0.8758815232722144, 'f1-score': 0.8880943868430461, 'support': 1418}

# %%
review = "Citizens don't pay you salaries to misbehave: Sumeet Vyas to Collectors, SDMs"
review_vector = vectorizer.transform([review])
print(classifier_linear.predict(review_vector))
# Out:
# ['fact']

# %%
prediction_linear
# Out:
# array(['fact', 'fact', 'opinion', ..., 'opinion', 'fact', 'fact'],
#       dtype=object)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test['CATEGORY'],prediction_linear)
# Out:
# array([[1242,  176],
#        [ 137, 1187]], dtype=int64)
